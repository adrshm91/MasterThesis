# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import *

# %%
file = "./amesim/model/DC_motor/speed.data"
df = pd.read_csv(file, sep="\s+", names=["time", "speed"],float_precision='round_trip')
df[:16000].plot(x = 'time', y = 'speed')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
df.head()
# Out:
#    time  speed
# 0  0.00    0.0
# 1  0.01    0.0
# 2  0.02    0.0
# 3  0.03    0.0
# 4  0.04    0.0

# %%
index = pd.date_range('1/1/2000', periods=len(df.index), freq='0.0000625S')
df.set_index(index, inplace=True)

# %%
df.head()
# Out:
#                                time  speed
# 2000-01-01 00:00:00.000000000  0.00    0.0
# 2000-01-01 00:00:00.000062500  0.01    0.0
# 2000-01-01 00:00:00.000125000  0.02    0.0
# 2000-01-01 00:00:00.000187500  0.03    0.0
# 2000-01-01 00:00:00.000250000  0.04    0.0

# %%
df[:16000].plot()
# Out:
# <div id='a8c80f7b-425c-46ea-8089-865d78097446'></div>
